# %%
from badptr_model import BadptrModel
from util import convert_tokens, evaluate, get_batch_dataset, get_dataset
import tensorflow as tf
from config import flags
import numpy as np
import json

# %%
def get_binary_record_parser(config, is_test=True):
    def parse(example):
        para_limit = config.test_para_limit if is_test else config.para_limit
        ques_limit = config.test_ques_limit if is_test else config.ques_limit
        char_limit = config.char_limit
        features = tf.parse_single_example(example,
                                           features={
                                               "context_idxs": tf.FixedLenFeature([], tf.string),
                                               "ques_idxs": tf.FixedLenFeature([], tf.string),
                                               "context_char_idxs": tf.FixedLenFeature([], tf.string),
                                               "ques_char_idxs": tf.FixedLenFeature([], tf.string),
                                               "id": tf.FixedLenFeature([], tf.int64),
                                               "y1": tf.FixedLenFeature([], tf.string),
                                               "y2": tf.FixedLenFeature([], tf.string),
                                           })
        context_idxs = tf.reshape(tf.decode_raw(
            features["context_idxs"], tf.int32), [para_limit])
        ques_idxs = tf.reshape(tf.decode_raw(
            features["ques_idxs"], tf.int32), [ques_limit])
        context_char_idxs = tf.reshape(tf.decode_raw(
            features["context_char_idxs"], tf.int32), [para_limit, char_limit])
        ques_char_idxs = tf.reshape(tf.decode_raw(
            features["ques_char_idxs"], tf.int32), [ques_limit, char_limit])
        qa_id = features["id"]
        y1 = tf.reshape(tf.decode_raw(
            features["y1"], tf.float32), [para_limit])
        y2 = tf.reshape(tf.decode_raw(
            features["y2"], tf.float32), [para_limit])
        return context_idxs, ques_idxs, context_char_idxs, ques_char_idxs, qa_id, y1, y2
    
    return parse

# %%
flags.DEFINE_string('f', 'give up already', 'who cares lol')
config = flags.FLAGS

# %%
parser = get_binary_record_parser(config)
train_dataset = get_batch_dataset('data/badptr_train.tf', parser, config)
dev_dataset = get_dataset('data/badptr_test.tf', parser, config)
handle = tf.placeholder(tf.string, shape=[])
iterator = tf.data.Iterator.from_string_handle(
    handle, train_dataset.output_types, train_dataset.output_shapes)
train_iterator = train_dataset.make_one_shot_iterator()
dev_iterator = dev_dataset.make_one_shot_iterator()

# %%
with open(config.word_emb_file, "r") as fh:
    word_mat = np.array(json.load(fh), dtype=np.float32)
with open(config.char_emb_file, "r") as fh:
    char_mat = np.array(json.load(fh), dtype=np.float32)

# %%
model = BadptrModel(config, iterator, word_mat, char_mat)
# Out:
# WARNING:tensorflow:From /home/soham/NLU-Project/env/local/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/datasets/base.py:198: retry (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use the retry module or similar alternatives.

# %%
sess_config = tf.ConfigProto(allow_soft_placement=True)
sess_config.gpu_options.allow_growth = True

sess = tf.Session(config=sess_config)

# %%
sess.run(tf.global_variables_initializer())
saver = tf.train.Saver(var_list=[v for v in tf.global_variables() if not v.name.startswith('badptr') and not v.name.startswith('binary/') and '/Adam' not in v.name and 'beta' not in v.name])
print('Restoring', tf.train.latest_checkpoint(config.save_dir))
saver.restore(sess, tf.train.latest_checkpoint(config.save_dir))
# Out:
# Restoring log/model/model_60000.ckpt
# INFO:tensorflow:Restoring parameters from log/model/model_60000.ckpt

# %%
best_acc = 0
saver2 = tf.train.Saver()

# %%
train_handle = sess.run(train_iterator.string_handle())
dev_handle = sess.run(dev_iterator.string_handle())

# %%
for _ in range(1, 5001):
    loss, train_op = sess.run([model.loss, model.train_op], feed_dict={
                              handle: train_handle})
    
    if _ % 10 == 0:
        print('After', _, 'iterations:')
        print('Batch Loss:', np.mean(loss))
    
    if _ % 100 == 0:
        acc = 0

        for __ in range(22):
            pred1, target1, pred2, target2 = sess.run([tf.argmax(model.y1, 1), model.yp1,
                                                       tf.argmax(model.y2, 1), model.yp2], feed_dict={handle: dev_handle})
            acc += np.mean(np.logical_and(pred1 == target1, pred2 == target2))

        acc /= float(22)
        print('Dev Accuracy:', acc)
        
        if acc > best_acc:
            best_acc = acc
            saver2.save(sess, 'log/badptr_model/badptr-savepoint', global_step=_)
    
    if _ % 10 == 0:
        print()
# Out:
# After 10 iterations:
# Batch Loss: 5.922181
#
# After 20 iterations:
# Batch Loss: 4.1139574
#
# After 30 iterations:
# Batch Loss: 2.996765
#
# After 40 iterations:
# Batch Loss: 1.9655526
#
# After 50 iterations:
# Batch Loss: 1.6397579
#
# After 60 iterations:
# Batch Loss: 0.8954891
#
# After 70 iterations:
# Batch Loss: 0.8677113
#
# After 80 iterations:
# Batch Loss: 0.715143
#
# After 90 iterations:
# Batch Loss: 1.017957
#
# After 100 iterations:
# Batch Loss: 0.47058624
# Dev Accuracy: 0.8693181818181818
#
# After 110 iterations:
# Batch Loss: 0.53084517
#
# After 120 iterations:
# Batch Loss: 0.4717941
#
# After 130 iterations:
# Batch Loss: 0.29515862
#
# After 140 iterations:
# Batch Loss: 0.21364745
#
# After 150 iterations:
# Batch Loss: 0.23698491
#
# After 160 iterations:
# Batch Loss: 0.22215614
#
# After 170 iterations:
# Batch Loss: 0.060447637
#
# After 180 iterations:
# Batch Loss: 0.17908046
#
# After 190 iterations:
# Batch Loss: 0.13392994
#
# After 200 iterations:
# Batch Loss: 0.29200798
# Dev Accuracy: 0.8821022727272727
#
# After 210 iterations:
# Batch Loss: 0.14438315
#
# After 220 iterations:
# Batch Loss: 0.43669006
#
# After 230 iterations:
# Batch Loss: 0.21131538
#
# After 240 iterations:
# Batch Loss: 0.041286085
#
# After 250 iterations:
# Batch Loss: 0.18332782
#
# After 260 iterations:
# Batch Loss: 0.120217696
#
# After 270 iterations:
# Batch Loss: 0.056663755
#
# After 280 iterations:
# Batch Loss: 0.21341717
#
# After 290 iterations:
# Batch Loss: 0.089494295
#
# After 300 iterations:
# Batch Loss: 0.16736867
# Dev Accuracy: 0.8863636363636364
#
# After 310 iterations:
# Batch Loss: 0.087791815
#
# After 320 iterations:
# Batch Loss: 0.07366811
#
# After 330 iterations:
# Batch Loss: 0.18931845
#
# After 340 iterations:
# Batch Loss: 0.03782899
#
# After 350 iterations:
# Batch Loss: 0.1918034
#
# After 360 iterations:
# Batch Loss: 0.039945997
#
# After 370 iterations:
# Batch Loss: 0.2150668
#
# After 380 iterations:
# Batch Loss: 0.07844101
#
# After 390 iterations:
# Batch Loss: 0.06578873
#
# After 400 iterations:
# Batch Loss: 0.02053379
# Dev Accuracy: 0.8778409090909091
#
# After 410 iterations:
# Batch Loss: 0.11842826
#
# After 420 iterations:
# Batch Loss: 0.14686215
#
# After 430 iterations:
# Batch Loss: 0.030553225
#
# After 440 iterations:
# Batch Loss: 0.102866426
#
# After 450 iterations:
# Batch Loss: 0.15366367
#
# After 460 iterations:
# Batch Loss: 0.04484387
#
# After 470 iterations:
# Batch Loss: 0.015962804
#
# After 480 iterations:
# Batch Loss: 0.19690058
#
# After 490 iterations:
# Batch Loss: 0.04269724
#
# After 500 iterations:
# Batch Loss: 0.069860935
# Dev Accuracy: 0.8757102272727273
#
# After 510 iterations:
# Batch Loss: 0.13890631
#
# After 520 iterations:
# Batch Loss: 0.054818563
#
# After 530 iterations:
# Batch Loss: 0.10813643
#
# After 540 iterations:
# Batch Loss: 0.031843334
#
# After 550 iterations:
# Batch Loss: 0.02404058
#
# After 560 iterations:
# Batch Loss: 0.2884291
#
# After 570 iterations:
# Batch Loss: 0.054525513
#
# After 580 iterations:
# Batch Loss: 0.029669862
#
# After 590 iterations:
# Batch Loss: 0.028958563
#
# After 600 iterations:
# Batch Loss: 0.100522235
# Dev Accuracy: 0.8991477272727273
#
# After 610 iterations:
# Batch Loss: 0.015165881
#
# After 620 iterations:
# Batch Loss: 0.09782389
#
# After 630 iterations:
# Batch Loss: 0.032123275
#
# After 640 iterations:
# Batch Loss: 0.024959158
#
# After 650 iterations:
# Batch Loss: 0.034794763
#
# After 660 iterations:
# Batch Loss: 0.046084106
#
# After 670 iterations:
# Batch Loss: 0.045562644
#
# After 680 iterations:
# Batch Loss: 0.019229798
#
# After 690 iterations:
# Batch Loss: 0.040626843
#
# After 700 iterations:
# Batch Loss: 0.054318737
# Dev Accuracy: 0.9041193181818182
#
# After 710 iterations:
# Batch Loss: 0.019473035
#
# After 720 iterations:
# Batch Loss: 0.030693017
#
# After 730 iterations:
# Batch Loss: 0.017317515
#
# After 740 iterations:
# Batch Loss: 0.032388326
#
# After 750 iterations:
# Batch Loss: 0.019594159
#
# After 760 iterations:
# Batch Loss: 0.07144399
#
# After 770 iterations:
# Batch Loss: 0.066725016
#
# After 780 iterations:
# Batch Loss: 0.136762
#
# After 790 iterations:
# Batch Loss: 0.025663778
#
# After 800 iterations:
# Batch Loss: 0.013574121
# Dev Accuracy: 0.9034090909090909
#
# After 810 iterations:
# Batch Loss: 0.036833756
#
# After 820 iterations:
# Batch Loss: 0.027078167
#
# After 830 iterations:
# Batch Loss: 0.016090192
#
# After 840 iterations:
# Batch Loss: 0.10759006
#
# After 850 iterations:
# Batch Loss: 0.007164388
#
# After 860 iterations:
# Batch Loss: 0.0054493635
#
# After 870 iterations:
# Batch Loss: 0.021026734
#
# After 880 iterations:
# Batch Loss: 0.007406822
#
# After 890 iterations:
# Batch Loss: 0.005443045
#
# After 900 iterations:
# Batch Loss: 0.020304434
# Dev Accuracy: 0.8892045454545454
#
# After 910 iterations:
# Batch Loss: 0.06984022
#
# After 920 iterations:
# Batch Loss: 0.011642002
#
# After 930 iterations:
# Batch Loss: 0.16194552
#
# After 940 iterations:
# Batch Loss: 0.010806423
#
# After 950 iterations:
# Batch Loss: 0.0066505405
#
# After 960 iterations:
# Batch Loss: 0.017798975
#
# After 970 iterations:
# Batch Loss: 0.06592166
#
# After 980 iterations:
# Batch Loss: 0.032410372
#
# After 990 iterations:
# Batch Loss: 0.012431535
#
# After 1000 iterations:
# Batch Loss: 0.006469452
# Dev Accuracy: 0.8934659090909091
#
# After 1010 iterations:
# Batch Loss: 0.1160768
#
# After 1020 iterations:
# Batch Loss: 0.07338295
#
# After 1030 iterations:
# Batch Loss: 0.13878492
#
# After 1040 iterations:
# Batch Loss: 0.0033936708
#
# After 1050 iterations:
# Batch Loss: 0.03909509
#
# After 1060 iterations:
# Batch Loss: 0.006785119
#
# After 1070 iterations:
# Batch Loss: 0.015852988
#
# After 1080 iterations:
# Batch Loss: 0.032697137
#
# After 1090 iterations:
# Batch Loss: 0.040172677
#
# After 1100 iterations:
# Batch Loss: 0.0128354775
# Dev Accuracy: 0.8977272727272727
#
# After 1110 iterations:
# Batch Loss: 0.063603655
#
# After 1120 iterations:
# Batch Loss: 0.0052932217
#
# After 1130 iterations:
# Batch Loss: 0.020058885
#
# After 1140 iterations:
# Batch Loss: 0.0110534495
#
# After 1150 iterations:
# Batch Loss: 0.02904898
#
# After 1160 iterations:
# Batch Loss: 0.006184081
#
# After 1170 iterations:
# Batch Loss: 0.048049357
#
# After 1180 iterations:
# Batch Loss: 0.0075790486
#
# After 1190 iterations:
# Batch Loss: 0.005546725
#
# After 1200 iterations:
# Batch Loss: 0.0094269095
# Dev Accuracy: 0.8877840909090909
#
# After 1210 iterations:
# Batch Loss: 0.0035694423
#
# After 1220 iterations:
# Batch Loss: 0.003596869
#
# After 1230 iterations:
# Batch Loss: 0.0034876452
#
# After 1240 iterations:
# Batch Loss: 0.0137094185
#
# After 1250 iterations:
# Batch Loss: 0.0056013763
#
# After 1260 iterations:
# Batch Loss: 0.0019636836
#
# After 1270 iterations:
# Batch Loss: 0.013505807
#
# After 1280 iterations:
# Batch Loss: 0.12875755
#
# After 1290 iterations:
# Batch Loss: 0.0037782283
#
# After 1300 iterations:
# Batch Loss: 0.018827235
# Dev Accuracy: 0.8913352272727273
#
# After 1310 iterations:
# Batch Loss: 0.0066015683
#
# After 1320 iterations:
# Batch Loss: 0.021340294
#
# After 1330 iterations:
# Batch Loss: 0.0025634433
#
# After 1340 iterations:
# Batch Loss: 0.0029502683
#
# After 1350 iterations:
# Batch Loss: 0.0053358767
#
# After 1360 iterations:
# Batch Loss: 0.00624503
#
# After 1370 iterations:
# Batch Loss: 0.020345356
#
# After 1380 iterations:
# Batch Loss: 0.00177464
#
# After 1390 iterations:
# Batch Loss: 0.0014295804
#
# After 1400 iterations:
# Batch Loss: 0.0031957617
# Dev Accuracy: 0.8934659090909091
#
# After 1410 iterations:
# Batch Loss: 0.0044680135
#
# After 1420 iterations:
# Batch Loss: 0.008211557
#
# After 1430 iterations:
# Batch Loss: 0.0062707663
#
# After 1440 iterations:
# Batch Loss: 0.037818305
#
# After 1450 iterations:
# Batch Loss: 0.03640255
#
# After 1460 iterations:
# Batch Loss: 0.008674804
#
# After 1470 iterations:
# Batch Loss: 0.0010568426
#
# After 1480 iterations:
# Batch Loss: 0.0036417
#
# After 1490 iterations:
# Batch Loss: 0.026239283
#
# After 1500 iterations:
# Batch Loss: 0.03708372
# Dev Accuracy: 0.9041193181818182
#
# After 1510 iterations:
# Batch Loss: 0.017974537
#
# After 1520 iterations:
# Batch Loss: 0.0020655585
#
# After 1530 iterations:
# Batch Loss: 0.007304915
#
# After 1540 iterations:
# Batch Loss: 0.0030651316
#
# After 1550 iterations:
# Batch Loss: 0.0035478761
#
# After 1560 iterations:
# Batch Loss: 0.0060020466
#
# After 1570 iterations:
# Batch Loss: 0.015603629
#
# After 1580 iterations:
# Batch Loss: 0.01566896
#
# After 1590 iterations:
# Batch Loss: 0.004774533
#
# After 1600 iterations:
# Batch Loss: 0.00916264
# Dev Accuracy: 0.8920454545454546
#
# After 1610 iterations:
# Batch Loss: 0.0041671875
#
# After 1620 iterations:
# Batch Loss: 0.022812793
#
# After 1630 iterations:
# Batch Loss: 0.0027520517
#
# After 1640 iterations:
# Batch Loss: 0.015143733
# After 1650 iterations:
# Batch Loss: 0.020501904
#
# After 1660 iterations:
# Batch Loss: 0.0028324784
#
# After 1670 iterations:
# Batch Loss: 0.01577081
#
# After 1680 iterations:
# Batch Loss: 0.028523773
#
# After 1690 iterations:
# Batch Loss: 0.006343873
#
# After 1700 iterations:
# Batch Loss: 0.0038378893
# Dev Accuracy: 0.8941761363636364
#
# After 1710 iterations:
# Batch Loss: 0.0049796714
#
# After 1720 iterations:
# Batch Loss: 0.024999402
#
# After 1730 iterations:
# Batch Loss: 0.004237912
#
# After 1740 iterations:
# Batch Loss: 0.011099955
#
# After 1750 iterations:
# Batch Loss: 0.007255056
#
# After 1760 iterations:
# Batch Loss: 0.0012623628
#
# After 1770 iterations:
# Batch Loss: 0.001203568
#
# After 1780 iterations:
# Batch Loss: 0.0064207935
#
# After 1790 iterations:
# Batch Loss: 0.0044747023
#
# After 1800 iterations:
# Batch Loss: 0.0010088858
# Dev Accuracy: 0.9055397727272727
#
# After 1810 iterations:
# Batch Loss: 0.00417831
#
# After 1820 iterations:
# Batch Loss: 0.002375898
#
# After 1830 iterations:
# Batch Loss: 0.0051789056
#
# After 1840 iterations:
# Batch Loss: 0.005590689
#
# After 1850 iterations:
# Batch Loss: 0.0017907044
#
# After 1860 iterations:
# Batch Loss: 0.024833567
#
# After 1870 iterations:
# Batch Loss: 0.0031649831
#
# After 1880 iterations:
# Batch Loss: 0.005939637
#
# After 1890 iterations:
# Batch Loss: 0.025390897
#
# After 1900 iterations:
# Batch Loss: 0.009707799
# Dev Accuracy: 0.8970170454545454
#
# After 1910 iterations:
# Batch Loss: 0.0073615066
#
# After 1920 iterations:
# Batch Loss: 0.01502166
#
# After 1930 iterations:
# Batch Loss: 0.019481955
#
# After 1940 iterations:
# Batch Loss: 0.00776123
#
# After 1950 iterations:
# Batch Loss: 0.0032806692
#
# After 1960 iterations:
# Batch Loss: 0.02354842
#
# After 1970 iterations:
# Batch Loss: 0.01652602
#
# After 1980 iterations:
# Batch Loss: 0.010369843
#
# After 1990 iterations:
# Batch Loss: 0.0044347113
#
# After 2000 iterations:
# Batch Loss: 0.019305969
# Dev Accuracy: 0.8948863636363636
#
# After 2010 iterations:
# Batch Loss: 0.0694877
#
# After 2020 iterations:
# Batch Loss: 0.0062471274
#
# After 2030 iterations:
# Batch Loss: 0.0020205854
#
# After 2040 iterations:
# Batch Loss: 0.0015120995
#
# After 2050 iterations:
# Batch Loss: 0.0081871655
#
# After 2060 iterations:
# Batch Loss: 0.03280783
#
# After 2070 iterations:
# Batch Loss: 0.09180643
#
# After 2080 iterations:
# Batch Loss: 0.010666133
#
# After 2090 iterations:
# Batch Loss: 0.066487856
#
# After 2100 iterations:
# Batch Loss: 0.030603265
# Dev Accuracy: 0.8927556818181818
#
# After 2110 iterations:
# Batch Loss: 0.005563875
#
# After 2120 iterations:
# Batch Loss: 0.009305637
#
# After 2130 iterations:
# Batch Loss: 0.0054420084
#
# After 2140 iterations:
# Batch Loss: 0.0043248264
#
# After 2150 iterations:
# Batch Loss: 0.012294019
#
# After 2160 iterations:
# Batch Loss: 0.0031734584
#
# After 2170 iterations:
# Batch Loss: 0.015861586
#
# After 2180 iterations:
# Batch Loss: 0.016514098
#
# After 2190 iterations:
# Batch Loss: 0.008941752
#
# After 2200 iterations:
# Batch Loss: 0.012594509
# Dev Accuracy: 0.9048295454545454
#
# After 2210 iterations:
# Batch Loss: 0.012779772
#
# After 2220 iterations:
# Batch Loss: 0.014080169
#
# After 2230 iterations:
# Batch Loss: 0.003080418
#
# After 2240 iterations:
# Batch Loss: 0.08395059
#
# After 2250 iterations:
# Batch Loss: 0.0045595146
#
# After 2260 iterations:
# Batch Loss: 0.0752087
#
# After 2270 iterations:
# Batch Loss: 0.02426545
#
# After 2280 iterations:
# Batch Loss: 0.009603797
#
# After 2290 iterations:
# Batch Loss: 0.013950693
#
# After 2300 iterations:
# Batch Loss: 0.013904115
# Dev Accuracy: 0.8742897727272727
#
# After 2310 iterations:
# Batch Loss: 0.017470783
#
# After 2320 iterations:
# Batch Loss: 0.018035308
#
# After 2330 iterations:
# Batch Loss: 0.0026289949
#
# After 2340 iterations:
# Batch Loss: 0.003225586
#
# After 2350 iterations:
# Batch Loss: 0.005193936
#
# After 2360 iterations:
# Batch Loss: 0.002765458
#
# After 2370 iterations:
# Batch Loss: 0.07622341
#
# After 2380 iterations:
# Batch Loss: 0.0022477221
#
# After 2390 iterations:
# Batch Loss: 0.014104012
#
# After 2400 iterations:
# Batch Loss: 0.020218907
# Dev Accuracy: 0.8870738636363636
#
# After 2410 iterations:
# Batch Loss: 0.005092431
#
# After 2420 iterations:
# Batch Loss: 0.0054575442
#
# After 2430 iterations:
# Batch Loss: 0.004627908
#
# After 2440 iterations:
# Batch Loss: 0.0070334496
#
# After 2450 iterations:
# Batch Loss: 0.007974883
#
# After 2460 iterations:
# Batch Loss: 0.0026484407
#
# After 2470 iterations:
# Batch Loss: 0.03602971
#
# After 2480 iterations:
# Batch Loss: 0.002188786
#
# After 2490 iterations:
# Batch Loss: 0.009224073
#
# After 2500 iterations:
# Batch Loss: 0.020395193
# Dev Accuracy: 0.8849431818181818
#
# After 2510 iterations:
# Batch Loss: 0.019209139
#
# After 2520 iterations:
# Batch Loss: 0.01766118
#
# After 2530 iterations:
# Batch Loss: 0.010269174
#
# After 2540 iterations:
# Batch Loss: 0.0063373167
#
# After 2550 iterations:
# Batch Loss: 0.04055998
#
# After 2560 iterations:
# Batch Loss: 0.007352638
#
# After 2570 iterations:
# Batch Loss: 0.036517948
#
# After 2580 iterations:
# Batch Loss: 0.004308776
#
# After 2590 iterations:
# Batch Loss: 0.0017265275
#
# After 2600 iterations:
# Batch Loss: 0.005271065
# Dev Accuracy: 0.8892045454545454
#
# After 2610 iterations:
# Batch Loss: 0.001690746
#
# After 2620 iterations:
# Batch Loss: 0.0020847705
#
# After 2630 iterations:
# Batch Loss: 0.028738435
#
# After 2640 iterations:
# Batch Loss: 0.0013772158
#
# After 2650 iterations:
# Batch Loss: 0.0015480329
#
# After 2660 iterations:
# Batch Loss: 0.006075887
#
# After 2670 iterations:
# Batch Loss: 0.011342942
#
# After 2680 iterations:
# Batch Loss: 0.002980195
#
# After 2690 iterations:
# Batch Loss: 0.026846448
#
# After 2700 iterations:
# Batch Loss: 0.012185937
# Dev Accuracy: 0.8884943181818182
#
# After 2710 iterations:
# Batch Loss: 0.029899843
#
# After 2720 iterations:
# Batch Loss: 0.005896705
#
# After 2730 iterations:
# Batch Loss: 0.008698144
#
# After 2740 iterations:
# Batch Loss: 0.0031724472
#
# After 2750 iterations:
# Batch Loss: 0.09865605
#
# After 2760 iterations:
# Batch Loss: 0.023400357
#
# After 2770 iterations:
# Batch Loss: 0.009650534
#
# After 2780 iterations:
# Batch Loss: 0.006864379
#
# After 2790 iterations:
# Batch Loss: 0.0020900033
#
# After 2800 iterations:
# Batch Loss: 0.013794814
# Dev Accuracy: 0.8963068181818182
#
# After 2810 iterations:
# Batch Loss: 0.004420718
#
# After 2820 iterations:
# Batch Loss: 0.003871066
#
# After 2830 iterations:
# Batch Loss: 0.021147508
#
# After 2840 iterations:
# Batch Loss: 0.0050035124
#
# After 2850 iterations:
# Batch Loss: 0.0035954895
#
# After 2860 iterations:
# Batch Loss: 0.0026530067
#
# After 2870 iterations:
# Batch Loss: 0.01141661
#
# After 2880 iterations:
# Batch Loss: 0.020395912
#
# After 2890 iterations:
# Batch Loss: 0.0017733983
#
# After 2900 iterations:
# Batch Loss: 0.0033590342
# Dev Accuracy: 0.8920454545454546
#
# After 2910 iterations:
# Batch Loss: 0.0020337347
#
# After 2920 iterations:
# Batch Loss: 0.0014647682
#
# After 2930 iterations:
# Batch Loss: 0.0057738125
#
# After 2940 iterations:
# Batch Loss: 0.012138254
#
# After 2950 iterations:
# Batch Loss: 0.006605562
#
# After 2960 iterations:
# Batch Loss: 0.0027966197
#
# After 2970 iterations:
# Batch Loss: 0.006294832
#
# After 2980 iterations:
# Batch Loss: 0.0043330444
#
# After 2990 iterations:
# Batch Loss: 0.050420612
#
# After 3000 iterations:
# Batch Loss: 0.016078226
# Dev Accuracy: 0.8700284090909091
#
# After 3010 iterations:
# Batch Loss: 0.0014357849
#
# After 3020 iterations:
# Batch Loss: 0.048957624
#
# After 3030 iterations:
# Batch Loss: 0.27825108
#
# After 3040 iterations:
# Batch Loss: 0.009102858
#
# After 3050 iterations:
# Batch Loss: 0.050183974
#
# After 3060 iterations:
# Batch Loss: 0.005032492
#
# After 3070 iterations:
# Batch Loss: 0.00941468
#
# After 3080 iterations:
# Batch Loss: 0.008811945
#
# After 3090 iterations:
# Batch Loss: 0.054791577
#
# After 3100 iterations:
# Batch Loss: 0.021110537
# Dev Accuracy: 0.8799715909090909
#
# After 3110 iterations:
# Batch Loss: 0.061931375
#
# After 3120 iterations:
# Batch Loss: 0.010143882
#
# After 3130 iterations:
# Batch Loss: 0.007879735
#
# After 3140 iterations:
# Batch Loss: 0.003137042
#
# After 3150 iterations:
# Batch Loss: 0.028530046
#
# After 3160 iterations:
# Batch Loss: 0.0810395
#
# After 3170 iterations:
# Batch Loss: 0.04397198
#
# After 3180 iterations:
# Batch Loss: 0.0079883225
#
# After 3190 iterations:
# Batch Loss: 0.013644887
#
# After 3200 iterations:
# Batch Loss: 0.008270777
# Dev Accuracy: 0.8806818181818182
#
# After 3210 iterations:
# Batch Loss: 0.021742132
#
# After 3220 iterations:
# Batch Loss: 0.2105074
#
# After 3230 iterations:
# Batch Loss: 0.0065252064
#
# After 3240 iterations:
# Batch Loss: 0.03624379
# After 3250 iterations:
# Batch Loss: 0.0048722234
#
# After 3260 iterations:
# Batch Loss: 0.0060374653
#
# After 3270 iterations:
# Batch Loss: 0.0029317725
#
# After 3280 iterations:
# Batch Loss: 0.0007659777
#
# After 3290 iterations:
# Batch Loss: 0.009216823
#
# After 3300 iterations:
# Batch Loss: 0.016468376
# Dev Accuracy: 0.8828125
#
# After 3310 iterations:
# Batch Loss: 0.008283488
#
# After 3320 iterations:
# Batch Loss: 0.0429844
#
# After 3330 iterations:
# Batch Loss: 0.014982239
#
# After 3340 iterations:
# Batch Loss: 0.009764947
#
# After 3350 iterations:
# Batch Loss: 0.0037746562
#
# After 3360 iterations:
# Batch Loss: 0.0043971604
#
# After 3370 iterations:
# Batch Loss: 0.01259387
#
# After 3380 iterations:
# Batch Loss: 0.078963056
#
# After 3390 iterations:
# Batch Loss: 0.011518665
#
# After 3400 iterations:
# Batch Loss: 0.005708976
# Dev Accuracy: 0.8785511363636364
#
# After 3410 iterations:
# Batch Loss: 0.0057197446
#
# After 3420 iterations:
# Batch Loss: 0.028168498
#
# After 3430 iterations:
# Batch Loss: 0.003565456
#
# After 3440 iterations:
# Batch Loss: 0.022034641
#
# After 3450 iterations:
# Batch Loss: 0.031300537
#
# After 3460 iterations:
# Batch Loss: 0.085037895
#
# After 3470 iterations:
# Batch Loss: 0.0077437316
#
# After 3480 iterations:
# Batch Loss: 0.027900612
#
# After 3490 iterations:
# Batch Loss: 0.004341761
#
# After 3500 iterations:
# Batch Loss: 0.007925961
# Dev Accuracy: 0.8899147727272727
#
# After 3510 iterations:
# Batch Loss: 0.0065178834
#
# After 3520 iterations:
# Batch Loss: 0.0020115795
#
# After 3530 iterations:
# Batch Loss: 0.013650799
#
# After 3540 iterations:
# Batch Loss: 0.013708134
#
# After 3550 iterations:
# Batch Loss: 0.0031576988
#
# After 3560 iterations:
# Batch Loss: 0.0246633
#
# After 3570 iterations:
# Batch Loss: 0.013874792
#
# After 3580 iterations:
# Batch Loss: 0.038853582
#
# After 3590 iterations:
# Batch Loss: 0.0015249997
#
# After 3600 iterations:
# Batch Loss: 0.016594509
# Dev Accuracy: 0.8884943181818182
#
# After 3610 iterations:
# Batch Loss: 0.0051225177
#
# After 3620 iterations:
# Batch Loss: 0.040219128
#
# After 3630 iterations:
# Batch Loss: 0.0063907085
#
# After 3640 iterations:
# Batch Loss: 0.006394982
#
# After 3650 iterations:
# Batch Loss: 0.0051470352
#
# After 3660 iterations:
# Batch Loss: 0.006237772
#
# After 3670 iterations:
# Batch Loss: 0.034740016
#
# After 3680 iterations:
# Batch Loss: 0.021290094
#
# After 3690 iterations:
# Batch Loss: 0.018098198
#
# After 3700 iterations:
# Batch Loss: 0.059568327
# Dev Accuracy: 0.8778409090909091
#
# After 3710 iterations:
# Batch Loss: 0.12523468
#
# After 3720 iterations:
# Batch Loss: 0.005696729
#
# After 3730 iterations:
# Batch Loss: 0.21271063
#
# After 3740 iterations:
# Batch Loss: 0.0034233525
#
# After 3750 iterations:
# Batch Loss: 0.008504005
#
# After 3760 iterations:
# Batch Loss: 0.0034838445
#
# After 3770 iterations:
# Batch Loss: 0.0027048842
#
# After 3780 iterations:
# Batch Loss: 0.011139981
#
# After 3790 iterations:
# Batch Loss: 0.001969269
#
# After 3800 iterations:
# Batch Loss: 0.012850865
# Dev Accuracy: 0.8927556818181818
#
# After 3810 iterations:
# Batch Loss: 0.012877235
#
# After 3820 iterations:
# Batch Loss: 0.0028244515
#
# After 3830 iterations:
# Batch Loss: 0.02284863
#
# After 3840 iterations:
# Batch Loss: 0.03336206
#
# After 3850 iterations:
# Batch Loss: 0.0030886058
#
# After 3860 iterations:
# Batch Loss: 0.015079552
#
# After 3870 iterations:
# Batch Loss: 0.0072665336
#
# After 3880 iterations:
# Batch Loss: 0.007993191
#
# After 3890 iterations:
# Batch Loss: 0.004259952
#
# After 3900 iterations:
# Batch Loss: 0.033192318
# Dev Accuracy: 0.890625
#
# After 3910 iterations:
# Batch Loss: 0.0023627288
#
# After 3920 iterations:
# Batch Loss: 0.0017477192
#
# After 3930 iterations:
# Batch Loss: 0.002073375
#
# After 3940 iterations:
# Batch Loss: 0.005805674
#
# After 3950 iterations:
# Batch Loss: 0.05460443
#
# After 3960 iterations:
# Batch Loss: 0.003168103
#
# After 3970 iterations:
# Batch Loss: 0.0082611125
#
# After 3980 iterations:
# Batch Loss: 0.0029137414
#
# After 3990 iterations:
# Batch Loss: 0.008837677
#
# After 4000 iterations:
# Batch Loss: 0.008032666
# Dev Accuracy: 0.8984375
#
# After 4010 iterations:
# Batch Loss: 0.004615378
#
# After 4020 iterations:
# Batch Loss: 0.001252158
#
# After 4030 iterations:
# Batch Loss: 0.002192412
#
# After 4040 iterations:
# Batch Loss: 0.007736737
#
# After 4050 iterations:
# Batch Loss: 0.013515395
#
# After 4060 iterations:
# Batch Loss: 0.012499724
#
# After 4070 iterations:
# Batch Loss: 0.016078314
#
# After 4080 iterations:
# Batch Loss: 0.015943933
#
# After 4090 iterations:
# Batch Loss: 0.0035611002
#
# After 4100 iterations:
# Batch Loss: 0.00157397
# Dev Accuracy: 0.8977272727272727
#
# After 4110 iterations:
# Batch Loss: 0.0008173757
#
# After 4120 iterations:
# Batch Loss: 0.019729538
#
# After 4130 iterations:
# Batch Loss: 0.0009968036
#
# After 4140 iterations:
# Batch Loss: 0.0017939457
#
# After 4150 iterations:
# Batch Loss: 0.014248395
#
# After 4160 iterations:
# Batch Loss: 0.0028506531
#
# After 4170 iterations:
# Batch Loss: 0.0052644447
#
# After 4180 iterations:
# Batch Loss: 0.0030203187
#
# After 4190 iterations:
# Batch Loss: 0.0099450555
#
# After 4200 iterations:
# Batch Loss: 0.0040574176
# Dev Accuracy: 0.8955965909090909
#
# After 4210 iterations:
# Batch Loss: 0.0014077637
#
# After 4220 iterations:
# Batch Loss: 0.0014092935
#
# After 4230 iterations:
# Batch Loss: 0.009183547
#
# After 4240 iterations:
# Batch Loss: 0.012259657
#
# After 4250 iterations:
# Batch Loss: 0.002652936
#
# After 4260 iterations:
# Batch Loss: 0.070003845
#
# After 4270 iterations:
# Batch Loss: 0.0027516917
#
# After 4280 iterations:
# Batch Loss: 0.009601247
#
# After 4290 iterations:
# Batch Loss: 0.0023389729
#
# After 4300 iterations:
# Batch Loss: 0.00076368183
# Dev Accuracy: 0.8998579545454546
#
# After 4310 iterations:
# Batch Loss: 0.004575946
#
# After 4320 iterations:
# Batch Loss: 0.0040460806
#
# After 4330 iterations:
# Batch Loss: 0.0155614605
#
# After 4340 iterations:
# Batch Loss: 0.007384968
#
# After 4350 iterations:
# Batch Loss: 0.0032729327
#
# After 4360 iterations:
# Batch Loss: 0.003484869
#
# After 4370 iterations:
# Batch Loss: 0.006127309
#
# After 4380 iterations:
# Batch Loss: 0.0012945962
#
# After 4390 iterations:
# Batch Loss: 0.075901896
#
# After 4400 iterations:
# Batch Loss: 0.0048327176
# Dev Accuracy: 0.8927556818181818
#
# After 4410 iterations:
# Batch Loss: 0.014213651
#
# After 4420 iterations:
# Batch Loss: 0.009101445
#
# After 4430 iterations:
# Batch Loss: 0.103470124
#
# After 4440 iterations:
# Batch Loss: 0.013136228
#
# After 4450 iterations:
# Batch Loss: 0.00057273376
#
# After 4460 iterations:
# Batch Loss: 0.0050524115
#
# After 4470 iterations:
# Batch Loss: 0.004371928
#
# After 4480 iterations:
# Batch Loss: 0.0050924635
#
# After 4490 iterations:
# Batch Loss: 0.01612261
#
# After 4500 iterations:
# Batch Loss: 0.010878226
# Dev Accuracy: 0.9026988636363636
#
# After 4510 iterations:
# Batch Loss: 0.04113747
#
# After 4520 iterations:
# Batch Loss: 0.0020246487
#
# After 4530 iterations:
# Batch Loss: 0.0047338456
#
# After 4540 iterations:
# Batch Loss: 0.0053041205
#
# After 4550 iterations:
# Batch Loss: 0.008322917
#
# After 4560 iterations:
# Batch Loss: 0.034249224
#
# After 4570 iterations:
# Batch Loss: 0.00068376656
#
# After 4580 iterations:
# Batch Loss: 0.005084126
#
# After 4590 iterations:
# Batch Loss: 0.00133801
#
# After 4600 iterations:
# Batch Loss: 0.0029535773
# Dev Accuracy: 0.9048295454545454
#
# After 4610 iterations:
# Batch Loss: 0.0024494831
#
# After 4620 iterations:
# Batch Loss: 0.001311285
#
# After 4630 iterations:
# Batch Loss: 0.06845347
#
# After 4640 iterations:
# Batch Loss: 0.00618661
#
# After 4650 iterations:
# Batch Loss: 0.0032753325
#
# After 4660 iterations:
# Batch Loss: 0.0057411394
#
# After 4670 iterations:
# Batch Loss: 0.00095802767
#
# After 4680 iterations:
# Batch Loss: 0.001730747
#
# After 4690 iterations:
# Batch Loss: 0.025206752
#
# After 4700 iterations:
# Batch Loss: 0.0040543
# Dev Accuracy: 0.8991477272727273
#
# After 4710 iterations:
# Batch Loss: 0.0019187162
#
# After 4720 iterations:
# Batch Loss: 0.007168216
#
# After 4730 iterations:
# Batch Loss: 0.0007357092
#
# After 4740 iterations:
# Batch Loss: 0.010628101
#
# After 4750 iterations:
# Batch Loss: 0.0020044306
#
# After 4760 iterations:
# Batch Loss: 0.0074775065
#
# After 4770 iterations:
# Batch Loss: 0.0019381819
#
# After 4780 iterations:
# Batch Loss: 0.005548448
#
# After 4790 iterations:
# Batch Loss: 0.0026971437
#
# After 4800 iterations:
# Batch Loss: 0.0012889837
# Dev Accuracy: 0.8977272727272727
#
# After 4810 iterations:
# Batch Loss: 0.0051270975
#
# After 4820 iterations:
# Batch Loss: 0.003986612
#
# After 4830 iterations:
# Batch Loss: 0.004400153
#
# After 4840 iterations:
# Batch Loss: 0.001946866
# After 4850 iterations:
# Batch Loss: 0.0011547569
#
# After 4860 iterations:
# Batch Loss: 0.0008485499
#
# After 4870 iterations:
# Batch Loss: 0.00075517676
#
# After 4880 iterations:
# Batch Loss: 0.0020396246
#
# After 4890 iterations:
# Batch Loss: 0.0023138113
#
# After 4900 iterations:
# Batch Loss: 0.0026717917
# Dev Accuracy: 0.9055397727272727
#
# After 4910 iterations:
# Batch Loss: 0.0022578223
#
# After 4920 iterations:
# Batch Loss: 0.114492275
#
# After 4930 iterations:
# Batch Loss: 0.04574908
#
# After 4940 iterations:
# Batch Loss: 0.0053581307
#
# After 4950 iterations:
# Batch Loss: 0.0041774455
#
# After 4960 iterations:
# Batch Loss: 0.009381839
#
# After 4970 iterations:
# Batch Loss: 0.0045275204
#
# After 4980 iterations:
# Batch Loss: 0.013010641
#
# After 4990 iterations:
# Batch Loss: 0.020453893
#
# After 5000 iterations:
# Batch Loss: 0.00083747215
# Dev Accuracy: 0.8955965909090909
