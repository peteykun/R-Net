# %%
from combo_model import ComboModel
from util import convert_tokens, get_batch_dataset, get_dataset, get_record_parser
import tensorflow as tf
from config import flags
import numpy as np
import json

# %%
flags.DEFINE_string('f', 'give up already', 'who cares lol')
config = flags.FLAGS

# %%
test_eval_file = 'data/combo_v2_test_meta.json'
test_record_file = 'data/combo_v2_test.tf'

with open(test_eval_file, "r") as fh:
    eval_file = json.load(fh)

meta = {'total': 1000}

# %%
with open(config.word_emb_file, "r") as fh:
    word_mat = np.array(json.load(fh), dtype=np.float32)
with open(config.char_emb_file, "r") as fh:
    char_mat = np.array(json.load(fh), dtype=np.float32)

# %%
def get_binary_record_parser(config, is_test=True):
    def parse(example):
        para_limit = config.test_para_limit if is_test else config.para_limit
        ques_limit = config.test_ques_limit if is_test else config.ques_limit
        char_limit = config.char_limit
        features = tf.parse_single_example(example,
                                           features={
                                               "context_idxs": tf.FixedLenFeature([], tf.string),
                                               "ques_idxs": tf.FixedLenFeature([], tf.string),
                                               "context_char_idxs": tf.FixedLenFeature([], tf.string),
                                               "ques_char_idxs": tf.FixedLenFeature([], tf.string),
                                               "id": tf.FixedLenFeature([], tf.int64),
                                               "bad_y1": tf.FixedLenFeature([], tf.string),
                                               "bad_y2": tf.FixedLenFeature([], tf.string),
                                               "y1": tf.FixedLenFeature([], tf.string),
                                               "y2": tf.FixedLenFeature([], tf.string),
                                           })
        context_idxs = tf.reshape(tf.decode_raw(
            features["context_idxs"], tf.int32), [para_limit])
        ques_idxs = tf.reshape(tf.decode_raw(
            features["ques_idxs"], tf.int32), [ques_limit])
        context_char_idxs = tf.reshape(tf.decode_raw(
            features["context_char_idxs"], tf.int32), [para_limit, char_limit])
        ques_char_idxs = tf.reshape(tf.decode_raw(
            features["ques_char_idxs"], tf.int32), [ques_limit, char_limit])
        qa_id = features["id"]
        bad_y1 = tf.reshape(tf.decode_raw(
            features["bad_y1"], tf.float32), [para_limit])
        bad_y2 = tf.reshape(tf.decode_raw(
            features["bad_y2"], tf.float32), [para_limit])
        y1 = tf.reshape(tf.decode_raw(
            features["y1"], tf.float32), [para_limit])
        y2 = tf.reshape(tf.decode_raw(
            features["y2"], tf.float32), [para_limit])
        return context_idxs, ques_idxs, context_char_idxs, ques_char_idxs, qa_id, bad_y1, bad_y2, y1, y2
    
    return parse

# %%
parser = get_binary_record_parser(config)
train_dataset = get_batch_dataset('data/combo_v2_train.tf', parser, config)
dev_dataset = get_dataset('data/combo_v2_test.tf', parser, config)
handle = tf.placeholder(tf.string, shape=[])
iterator = tf.data.Iterator.from_string_handle(
    handle, train_dataset.output_types, train_dataset.output_shapes)
train_iterator = train_dataset.make_one_shot_iterator()
dev_iterator = dev_dataset.make_one_shot_iterator()

# %%
model = ComboModel(config, iterator, word_mat, char_mat)
# Out:
# WARNING:tensorflow:From /home/soham/NLU-Project/env/local/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/datasets/base.py:198: retry (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use the retry module or similar alternatives.
# RUN ASSIGN TRICK OPS (model.assign_trick_ops)!!

# %%
sess_config = tf.ConfigProto(allow_soft_placement=True)
sess_config.gpu_options.allow_growth = True

sess = tf.Session(config=sess_config)

# %%
sess.run(tf.global_variables_initializer())
saver = tf.train.Saver(var_list=[v for v in tf.global_variables() if not v.name.startswith('encoding_1/') and not v.name.startswith('badptr') and '/Adam' not in v.name and 'beta' not in v.name])
print('Restoring', tf.train.latest_checkpoint(config.save_dir))
saver.restore(sess, tf.train.latest_checkpoint(config.save_dir))
sess.run(model.assign_trick_ops)
sess.run(tf.assign(model.is_train, tf.constant(True, dtype=tf.bool)))
# Out:
# Restoring log/model/model_60000.ckpt
# INFO:tensorflow:Restoring parameters from log/model/model_60000.ckpt
# True

# %%
encoding_1_vars = sorted([(v.name, v) for v in tf.global_variables() if v.name.startswith('encoding_1/Variable')])
encoding_vars = sorted([(v.name, v) for v in tf.global_variables() if v.name.startswith('encoding/Variable')])

# %%
for (n1, e1v), (n, ev) in zip(encoding_1_vars, encoding_vars):
    assert n1.split('/')[1] == n.split('/')[1]
    e1v_val, ev_val = sess.run([e1v, ev])
    assert np.linalg.norm(e1v_val - ev_val) < 1e-10

# %%
best_acc = 0
saver2 = tf.train.Saver()
train_handle = sess.run(train_iterator.string_handle())
dev_handle = sess.run(dev_iterator.string_handle())

# %%
for _ in range(1, 5001):
    loss, train_op = sess.run([model.loss, model.train_op], feed_dict={
                              handle: train_handle})
    
    if _ % 10 == 0:
        print('After', _, 'iterations:')
        print('Batch Loss:', np.mean(loss))
    
    if _ % 100 == 0:
        acc = 0

        for __ in range(22):
            pred1, target1, pred2, target2 = sess.run([tf.argmax(model.bad_y1, 1), model.bad_yp1,
                                                       tf.argmax(model.bad_y2, 1), model.bad_yp2], feed_dict={handle: dev_handle})
            acc += np.mean(np.logical_and(pred1 == target1, pred2 == target2))

        acc /= float(22)
        print('Dev Accuracy:', acc)
        
        if acc > best_acc:
            best_acc = acc
            saver2.save(sess, 'log/combo_model/badptr-savepoint', global_step=_)
    
    if _ % 10 == 0:
        print()
# Out:
# After 10 iterations:
# Batch Loss: 5.4161797
#
# After 20 iterations:
# Batch Loss: 4.7621365
#
# After 30 iterations:
# Batch Loss: 4.166677
#
# After 40 iterations:
# Batch Loss: 3.2321475
#
# After 50 iterations:
# Batch Loss: 3.3673484
#
# After 60 iterations:
# Batch Loss: 3.1178713
#
# After 70 iterations:
# Batch Loss: 2.7015762
#
# After 80 iterations:
# Batch Loss: 2.2041872
#
# After 90 iterations:
# Batch Loss: 1.7988122
#
# After 100 iterations:
# Batch Loss: 1.7977811
# Dev Accuracy: 0.6981534090909091
#
# After 110 iterations:
# Batch Loss: 1.1279154
#
# After 120 iterations:
# Batch Loss: 1.5531837
#
# After 130 iterations:
# Batch Loss: 1.552281
#
# After 140 iterations:
# Batch Loss: 0.748489
#
# After 150 iterations:
# Batch Loss: 0.92454183
#
# After 160 iterations:
# Batch Loss: 1.0439746
#
# After 170 iterations:
# Batch Loss: 1.0651668
#
# After 180 iterations:
# Batch Loss: 0.39612645
#
# After 190 iterations:
# Batch Loss: 0.6495237
#
# After 200 iterations:
# Batch Loss: 1.0986636
# Dev Accuracy: 0.7947443181818182
#
# After 210 iterations:
# Batch Loss: 0.43030694
#
# After 220 iterations:
# Batch Loss: 0.39884728
#
# After 230 iterations:
# Batch Loss: 0.64574456
#
# After 240 iterations:
# Batch Loss: 0.5575737
#
# After 250 iterations:
# Batch Loss: 0.45843735
#
# After 260 iterations:
# Batch Loss: 0.49664187
#
# After 270 iterations:
# Batch Loss: 0.19453463
#
# After 280 iterations:
# Batch Loss: 0.12139784
#
# After 290 iterations:
# Batch Loss: 0.18812618
#
# After 300 iterations:
# Batch Loss: 0.13875724
# Dev Accuracy: 0.8238636363636364
#
# After 310 iterations:
# Batch Loss: 0.17632706
#
# After 320 iterations:
# Batch Loss: 0.20019823
#
# After 330 iterations:
# Batch Loss: 0.2656501
#
# After 340 iterations:
# Batch Loss: 0.3222729
#
# After 350 iterations:
# Batch Loss: 0.19332096
#
# After 360 iterations:
# Batch Loss: 0.22841609
#
# After 370 iterations:
# Batch Loss: 0.1995241
#
# After 380 iterations:
# Batch Loss: 0.33776268
#
# After 390 iterations:
# Batch Loss: 0.07860032
#
# After 400 iterations:
# Batch Loss: 0.124087885
# Dev Accuracy: 0.8387784090909091
#
# After 410 iterations:
# Batch Loss: 0.39146045
#
# After 420 iterations:
# Batch Loss: 0.11675908
#
# After 430 iterations:
# Batch Loss: 0.17650434
#
# After 440 iterations:
# Batch Loss: 0.35832694
#
# After 450 iterations:
# Batch Loss: 0.26253253
#
# After 460 iterations:
# Batch Loss: 0.16938424
#
# After 470 iterations:
# Batch Loss: 0.08240168
#
# After 480 iterations:
# Batch Loss: 0.20084643
#
# After 490 iterations:
# Batch Loss: 0.106657594
#
# After 500 iterations:
# Batch Loss: 0.26966548
# Dev Accuracy: 0.8309659090909091
#
# After 510 iterations:
# Batch Loss: 0.21724327
#
# After 520 iterations:
# Batch Loss: 0.19960603
#
# After 530 iterations:
# Batch Loss: 0.12394585
#
# After 540 iterations:
# Batch Loss: 0.10493389
#
# After 550 iterations:
# Batch Loss: 0.11301117
#
# After 560 iterations:
# Batch Loss: 0.14088675
#
# After 570 iterations:
# Batch Loss: 0.13681996
#
# After 580 iterations:
# Batch Loss: 0.29564774
#
# After 590 iterations:
# Batch Loss: 0.041429974
#
# After 600 iterations:
# Batch Loss: 0.033876304
# Dev Accuracy: 0.8359375
#
# After 610 iterations:
# Batch Loss: 0.06272182
#
# After 620 iterations:
# Batch Loss: 0.04626344
#
# After 630 iterations:
# Batch Loss: 0.11447817
#
# After 640 iterations:
# Batch Loss: 0.076048404
#
# After 650 iterations:
# Batch Loss: 0.0741014
#
# After 660 iterations:
# Batch Loss: 0.06028693
#
# After 670 iterations:
# Batch Loss: 0.29779884
#
# After 680 iterations:
# Batch Loss: 0.033495516
#
# After 690 iterations:
# Batch Loss: 0.30030912
#
# After 700 iterations:
# Batch Loss: 0.07866938
# Dev Accuracy: 0.8473011363636364
#
# After 710 iterations:
# Batch Loss: 0.1374839
#
# After 720 iterations:
# Batch Loss: 0.0794909
#
# After 730 iterations:
# Batch Loss: 0.22978039
#
# After 740 iterations:
# Batch Loss: 0.20242997
#
# After 750 iterations:
# Batch Loss: 0.16303319
#
# After 760 iterations:
# Batch Loss: 0.08736283
#
# After 770 iterations:
# Batch Loss: 0.15612066
#
# After 780 iterations:
# Batch Loss: 0.13609187
#
# After 790 iterations:
# Batch Loss: 0.053648405
#
# After 800 iterations:
# Batch Loss: 0.08584407
# Dev Accuracy: 0.8231534090909091
#
# After 810 iterations:
# Batch Loss: 0.08899544
#
# After 820 iterations:
# Batch Loss: 0.046467092
#
# After 830 iterations:
# Batch Loss: 0.021109913
#
# After 840 iterations:
# Batch Loss: 0.016654106
#
# After 850 iterations:
# Batch Loss: 0.11173061
#
# After 860 iterations:
# Batch Loss: 0.08527531
#
# After 870 iterations:
# Batch Loss: 0.2000265
#
# After 880 iterations:
# Batch Loss: 0.025163373
#
# After 890 iterations:
# Batch Loss: 0.014029248
#
# After 900 iterations:
# Batch Loss: 0.11320005
# Dev Accuracy: 0.8451704545454546
#
# After 910 iterations:
# Batch Loss: 0.13050261
#
# After 920 iterations:
# Batch Loss: 0.03691835
#
# After 930 iterations:
# Batch Loss: 0.03501389
#
# After 940 iterations:
# Batch Loss: 0.028287493
#
# After 950 iterations:
# Batch Loss: 0.016398877
#
# After 960 iterations:
# Batch Loss: 0.23927832
#
# After 970 iterations:
# Batch Loss: 0.04767679
#
# After 980 iterations:
# Batch Loss: 0.07776327
#
# After 990 iterations:
# Batch Loss: 0.15858017
#
# After 1000 iterations:
# Batch Loss: 0.15221713
# Dev Accuracy: 0.8394886363636364
#
# After 1010 iterations:
# Batch Loss: 0.03614746
#
# After 1020 iterations:
# Batch Loss: 0.031037213
#
# After 1030 iterations:
# Batch Loss: 0.01633674
#
# After 1040 iterations:
# Batch Loss: 0.02330833
#
# After 1050 iterations:
# Batch Loss: 0.024032675
#
# After 1060 iterations:
# Batch Loss: 0.03725185
#
# After 1070 iterations:
# Batch Loss: 0.020502262
#
# After 1080 iterations:
# Batch Loss: 0.14758788
#
# After 1090 iterations:
# Batch Loss: 0.08359844
#
# After 1100 iterations:
# Batch Loss: 0.025882013
# Dev Accuracy: 0.8536931818181818
#
# After 1110 iterations:
# Batch Loss: 0.2661456
#
# After 1120 iterations:
# Batch Loss: 0.13413797
#
# After 1130 iterations:
# Batch Loss: 0.031428337
#
# After 1140 iterations:
# Batch Loss: 0.0542519
#
# After 1150 iterations:
# Batch Loss: 0.029953739
#
# After 1160 iterations:
# Batch Loss: 0.015835615
#
# After 1170 iterations:
# Batch Loss: 0.034502335
#
# After 1180 iterations:
# Batch Loss: 0.03795686
#
# After 1190 iterations:
# Batch Loss: 0.11406751
#
# After 1200 iterations:
# Batch Loss: 0.006540047
# Dev Accuracy: 0.8643465909090909
#
# After 1210 iterations:
# Batch Loss: 0.08187165
#
# After 1220 iterations:
# Batch Loss: 0.02985347
#
# After 1230 iterations:
# Batch Loss: 0.2608705
#
# After 1240 iterations:
# Batch Loss: 0.0056413775
#
# After 1250 iterations:
# Batch Loss: 0.009125083
#
# After 1260 iterations:
# Batch Loss: 0.018275635
#
# After 1270 iterations:
# Batch Loss: 0.021397218
#
# After 1280 iterations:
# Batch Loss: 0.011298998
#
# After 1290 iterations:
# Batch Loss: 0.014112311
#
# After 1300 iterations:
# Batch Loss: 0.043958824
# Dev Accuracy: 0.8522727272727273
#
# After 1310 iterations:
# Batch Loss: 0.030618368
#
# After 1320 iterations:
# Batch Loss: 0.22921015
#
# After 1330 iterations:
# Batch Loss: 0.030869171
#
# After 1340 iterations:
# Batch Loss: 0.013223705
#
# After 1350 iterations:
# Batch Loss: 0.030129183
#
# After 1360 iterations:
# Batch Loss: 0.026020428
#
# After 1370 iterations:
# Batch Loss: 0.012609426
#
# After 1380 iterations:
# Batch Loss: 0.010423912
#
# After 1390 iterations:
# Batch Loss: 0.051028892
#
# After 1400 iterations:
# Batch Loss: 0.022868227
# Dev Accuracy: 0.8607954545454546
#
# After 1410 iterations:
# Batch Loss: 0.028869418
#
# After 1420 iterations:
# Batch Loss: 0.004817028
#
# After 1430 iterations:
# Batch Loss: 0.019875906
#
# After 1440 iterations:
# Batch Loss: 0.09826629
#
# After 1450 iterations:
# Batch Loss: 0.0074437237
#
# After 1460 iterations:
# Batch Loss: 0.025106817
#
# After 1470 iterations:
# Batch Loss: 0.10314892
#
# After 1480 iterations:
# Batch Loss: 0.021769203
#
# After 1490 iterations:
# Batch Loss: 0.00890286
#
# After 1500 iterations:
# Batch Loss: 0.043883756
# Dev Accuracy: 0.8501420454545454
#
# After 1510 iterations:
# Batch Loss: 0.01019657
#
# After 1520 iterations:
# Batch Loss: 0.067364216
#
# After 1530 iterations:
# Batch Loss: 0.009948917
#
# After 1540 iterations:
# Batch Loss: 0.019931385
#
# After 1550 iterations:
# Batch Loss: 0.053543538
#
# After 1560 iterations:
# Batch Loss: 0.008732126
#
# After 1570 iterations:
# Batch Loss: 0.08790685
#
# After 1580 iterations:
# Batch Loss: 0.08532174
#
# After 1590 iterations:
# Batch Loss: 0.010632844
#
# After 1600 iterations:
# Batch Loss: 0.01654616
# Dev Accuracy: 0.8565340909090909
#
# After 1610 iterations:
# Batch Loss: 0.008879326
#
# After 1620 iterations:
# Batch Loss: 0.024425477
#
# After 1630 iterations:
# Batch Loss: 0.0080398135
#
# After 1640 iterations:
# Batch Loss: 0.188036
#
# After 1650 iterations:
# Batch Loss: 0.03827525
#
# After 1660 iterations:
# Batch Loss: 0.0032216469
# After 1670 iterations:
# Batch Loss: 0.007527422
#
# After 1680 iterations:
# Batch Loss: 0.014398581
#
# After 1690 iterations:
# Batch Loss: 0.06132517
#
# After 1700 iterations:
# Batch Loss: 0.09674517
# Dev Accuracy: 0.8501420454545454
#
# After 1710 iterations:
# Batch Loss: 0.0043999436
#
# After 1720 iterations:
# Batch Loss: 0.096353814
#
# After 1730 iterations:
# Batch Loss: 0.13751595
#
# After 1740 iterations:
# Batch Loss: 0.066489205
#
# After 1750 iterations:
# Batch Loss: 0.003518252
#
# After 1760 iterations:
# Batch Loss: 0.019687088
#
# After 1770 iterations:
# Batch Loss: 0.027850691
#
# After 1780 iterations:
# Batch Loss: 0.004118139
#
# After 1790 iterations:
# Batch Loss: 0.11529322
#
# After 1800 iterations:
# Batch Loss: 0.0056443596
# Dev Accuracy: 0.8544034090909091
#
# After 1810 iterations:
# Batch Loss: 0.0063931714
#
# After 1820 iterations:
# Batch Loss: 0.012171693
#
# After 1830 iterations:
# Batch Loss: 0.0020232403
#
# After 1840 iterations:
# Batch Loss: 0.014215855
#
# After 1850 iterations:
# Batch Loss: 0.0018027266
#
# After 1860 iterations:
# Batch Loss: 0.0075568464
#
# After 1870 iterations:
# Batch Loss: 0.028423827
#
# After 1880 iterations:
# Batch Loss: 0.009186396
#
# After 1890 iterations:
# Batch Loss: 0.023215532
#
# After 1900 iterations:
# Batch Loss: 0.0051383525
# Dev Accuracy: 0.8586647727272727
#
# After 1910 iterations:
# Batch Loss: 0.0130126905
#
# After 1920 iterations:
# Batch Loss: 0.019629294
#
# After 1930 iterations:
# Batch Loss: 0.005107004
#
# After 1940 iterations:
# Batch Loss: 0.093296476
#
# After 1950 iterations:
# Batch Loss: 0.011051213
#
# After 1960 iterations:
# Batch Loss: 0.008144046
#
# After 1970 iterations:
# Batch Loss: 0.062358893
#
# After 1980 iterations:
# Batch Loss: 0.0063542165
#
# After 1990 iterations:
# Batch Loss: 0.0021647033
#
# After 2000 iterations:
# Batch Loss: 0.010355221
# Dev Accuracy: 0.8650568181818182
#
# After 2010 iterations:
# Batch Loss: 0.04801558
#
# After 2020 iterations:
# Batch Loss: 0.0071368404
#
# After 2030 iterations:
# Batch Loss: 0.0399009
#
# After 2040 iterations:
# Batch Loss: 0.038277872
#
# After 2050 iterations:
# Batch Loss: 0.05264666
#
# After 2060 iterations:
# Batch Loss: 0.010766506
#
# After 2070 iterations:
# Batch Loss: 0.0184606
#
# After 2080 iterations:
# Batch Loss: 0.010941791
#
# After 2090 iterations:
# Batch Loss: 0.08350466
#
# After 2100 iterations:
# Batch Loss: 0.03634861
# Dev Accuracy: 0.8622159090909091
#
# After 2110 iterations:
# Batch Loss: 0.09112191
#
# After 2120 iterations:
# Batch Loss: 0.009960512
#
# After 2130 iterations:
# Batch Loss: 0.030701954
#
# After 2140 iterations:
# Batch Loss: 0.022083385
#
# After 2150 iterations:
# Batch Loss: 0.006335614
#
# After 2160 iterations:
# Batch Loss: 0.030228537
#
# After 2170 iterations:
# Batch Loss: 0.011440968
#
# After 2180 iterations:
# Batch Loss: 0.004837109
#
# After 2190 iterations:
# Batch Loss: 0.012378402
#
# After 2200 iterations:
# Batch Loss: 0.011149405
# Dev Accuracy: 0.8636363636363636
#
# After 2210 iterations:
# Batch Loss: 0.06345787
#
# After 2220 iterations:
# Batch Loss: 0.024903715
#
# After 2230 iterations:
# Batch Loss: 0.0057723336
#
# After 2240 iterations:
# Batch Loss: 0.009690046
#
# After 2250 iterations:
# Batch Loss: 0.014463094
#
# After 2260 iterations:
# Batch Loss: 0.0024351745
#
# After 2270 iterations:
# Batch Loss: 0.012664948
#
# After 2280 iterations:
# Batch Loss: 0.08427064
#
# After 2290 iterations:
# Batch Loss: 0.016592883
#
# After 2300 iterations:
# Batch Loss: 0.002684135
# Dev Accuracy: 0.8558238636363636
#
# After 2310 iterations:
# Batch Loss: 0.0029724198
#
# After 2320 iterations:
# Batch Loss: 0.018803827
#
# After 2330 iterations:
# Batch Loss: 0.007971093
#
# After 2340 iterations:
# Batch Loss: 0.027143817
#
# After 2350 iterations:
# Batch Loss: 0.022128953
#
# After 2360 iterations:
# Batch Loss: 0.022466775
#
# After 2370 iterations:
# Batch Loss: 0.005384426
#
# After 2380 iterations:
# Batch Loss: 0.030868752
#
# After 2390 iterations:
# Batch Loss: 0.023107426
#
# After 2400 iterations:
# Batch Loss: 0.17899561
# Dev Accuracy: 0.8551136363636364
#
# After 2410 iterations:
# Batch Loss: 0.025632035
#
# After 2420 iterations:
# Batch Loss: 0.004060267
#
# After 2430 iterations:
# Batch Loss: 0.0022895357
#
# After 2440 iterations:
# Batch Loss: 0.049987156
#
# After 2450 iterations:
# Batch Loss: 0.018204076
#
# After 2460 iterations:
# Batch Loss: 0.015382508
#
# After 2470 iterations:
# Batch Loss: 0.0075765457
#
# After 2480 iterations:
# Batch Loss: 0.049447965
#
# After 2490 iterations:
# Batch Loss: 0.003634987
#
# After 2500 iterations:
# Batch Loss: 0.0034296885
# Dev Accuracy: 0.8558238636363636
#
# After 2510 iterations:
# Batch Loss: 0.004049619
#
# After 2520 iterations:
# Batch Loss: 0.0493576
#
# After 2530 iterations:
# Batch Loss: 0.016038759
#
# After 2540 iterations:
# Batch Loss: 0.0013643014
#
# After 2550 iterations:
# Batch Loss: 0.00211245
#
# After 2560 iterations:
# Batch Loss: 0.038165763
#
# After 2570 iterations:
# Batch Loss: 0.010140095
#
# After 2580 iterations:
# Batch Loss: 0.002204371
#
# After 2590 iterations:
# Batch Loss: 0.010532441
#
# After 2600 iterations:
# Batch Loss: 0.0118826935
# Dev Accuracy: 0.8487215909090909
#
# After 2610 iterations:
# Batch Loss: 0.045396663
#
# After 2620 iterations:
# Batch Loss: 0.010232488
#
# After 2630 iterations:
# Batch Loss: 0.050011005
#
# After 2640 iterations:
# Batch Loss: 0.050705228
#
# After 2650 iterations:
# Batch Loss: 0.0021184091
#
# After 2660 iterations:
# Batch Loss: 0.09747342
#
# After 2670 iterations:
# Batch Loss: 0.012517067
#
# After 2680 iterations:
# Batch Loss: 0.13863263
#
# After 2690 iterations:
# Batch Loss: 0.2431952
#
# After 2700 iterations:
# Batch Loss: 0.005809906
# Dev Accuracy: 0.8636363636363636
#
# After 2710 iterations:
# Batch Loss: 0.00503576
#
# After 2720 iterations:
# Batch Loss: 0.008205412
#
# After 2730 iterations:
# Batch Loss: 0.056039806
#
# After 2740 iterations:
# Batch Loss: 0.033858623
#
# After 2750 iterations:
# Batch Loss: 0.009715994
#
# After 2760 iterations:
# Batch Loss: 0.016937979
#
# After 2770 iterations:
# Batch Loss: 0.076834515
#
# After 2780 iterations:
# Batch Loss: 0.07063197
#
# After 2790 iterations:
# Batch Loss: 0.0064926576
#
# After 2800 iterations:
# Batch Loss: 0.04556323
# Dev Accuracy: 0.8650568181818182
#
# After 2810 iterations:
# Batch Loss: 0.1644567
#
# After 2820 iterations:
# Batch Loss: 0.020723244
#
# After 2830 iterations:
# Batch Loss: 0.022092074
#
# After 2840 iterations:
# Batch Loss: 0.021679454
#
# After 2850 iterations:
# Batch Loss: 0.004815359
#
# After 2860 iterations:
# Batch Loss: 0.011037325
#
# After 2870 iterations:
# Batch Loss: 0.012377404
#
# After 2880 iterations:
# Batch Loss: 0.006676106
#
# After 2890 iterations:
# Batch Loss: 0.0060625263
#
# After 2900 iterations:
# Batch Loss: 0.03168896
# Dev Accuracy: 0.8664772727272727
#
# After 2910 iterations:
# Batch Loss: 0.016734801
#
# After 2920 iterations:
# Batch Loss: 0.018599631
#
# After 2930 iterations:
# Batch Loss: 0.013173794
#
# After 2940 iterations:
# Batch Loss: 0.0016370977
#
# After 2950 iterations:
# Batch Loss: 0.01899834
#
# After 2960 iterations:
# Batch Loss: 0.007253039
#
# After 2970 iterations:
# Batch Loss: 0.19060673
#
# After 2980 iterations:
# Batch Loss: 0.068717405
#
# After 2990 iterations:
# Batch Loss: 0.16426395
#
# After 3000 iterations:
# Batch Loss: 0.022147138
# Dev Accuracy: 0.8416193181818182
#
# After 3010 iterations:
# Batch Loss: 0.0028254716
#
# After 3020 iterations:
# Batch Loss: 0.019568017
#
# After 3030 iterations:
# Batch Loss: 0.09236241
#
# After 3040 iterations:
# Batch Loss: 0.023760518
#
# After 3050 iterations:
# Batch Loss: 0.0074966457
#
# After 3060 iterations:
# Batch Loss: 0.010068138
#
# After 3070 iterations:
# Batch Loss: 0.0260478
#
# After 3080 iterations:
# Batch Loss: 0.010201994
#
# After 3090 iterations:
# Batch Loss: 0.020227328
#
# After 3100 iterations:
# Batch Loss: 0.025036445
# Dev Accuracy: 0.8522727272727273
#
# After 3110 iterations:
# Batch Loss: 0.033176806
#
# After 3120 iterations:
# Batch Loss: 0.014687844
#
# After 3130 iterations:
# Batch Loss: 0.011948803
#
# After 3140 iterations:
# Batch Loss: 0.001873973
#
# After 3150 iterations:
# Batch Loss: 0.026249638
#
# After 3160 iterations:
# Batch Loss: 0.204658
#
# After 3170 iterations:
# Batch Loss: 0.009458711
#
# After 3180 iterations:
# Batch Loss: 0.0010316172
#
# After 3190 iterations:
# Batch Loss: 0.0045882915
#
# After 3200 iterations:
# Batch Loss: 0.024739005
# Dev Accuracy: 0.8579545454545454
#
# After 3210 iterations:
# Batch Loss: 0.008656216
#
# After 3220 iterations:
# Batch Loss: 0.010472381
#
# After 3230 iterations:
# Batch Loss: 0.0082819
#
# After 3240 iterations:
# Batch Loss: 0.022446882
#
# After 3250 iterations:
# Batch Loss: 0.045948733
#
# After 3260 iterations:
# Batch Loss: 0.010769545
# After 3270 iterations:
# Batch Loss: 0.0017322395
#
# After 3280 iterations:
# Batch Loss: 0.0044734683
#
# After 3290 iterations:
# Batch Loss: 0.022527684
#
# After 3300 iterations:
# Batch Loss: 0.009697869
# Dev Accuracy: 0.8622159090909091
#
# After 3310 iterations:
# Batch Loss: 0.0018611788
#
# After 3320 iterations:
# Batch Loss: 0.002323562
#
# After 3330 iterations:
# Batch Loss: 0.01726541
#
# After 3340 iterations:
# Batch Loss: 0.005984817
#
# After 3350 iterations:
# Batch Loss: 0.004765146
#
# After 3360 iterations:
# Batch Loss: 0.0020371901
#
# After 3370 iterations:
# Batch Loss: 0.0045574983
#
# After 3380 iterations:
# Batch Loss: 0.0074246144
#
# After 3390 iterations:
# Batch Loss: 0.007856004
#
# After 3400 iterations:
# Batch Loss: 0.07888506
# Dev Accuracy: 0.8494318181818182
#
# After 3410 iterations:
# Batch Loss: 0.019822482
#
# After 3420 iterations:
# Batch Loss: 0.030942213
#
# After 3430 iterations:
# Batch Loss: 0.011313289
#
# After 3440 iterations:
# Batch Loss: 0.0077142944
#
# After 3450 iterations:
# Batch Loss: 0.17415063
#
# After 3460 iterations:
# Batch Loss: 0.017751556
#
# After 3470 iterations:
# Batch Loss: 0.0048638065
#
# After 3480 iterations:
# Batch Loss: 0.05854907
#
# After 3490 iterations:
# Batch Loss: 0.07010021
#
# After 3500 iterations:
# Batch Loss: 0.041783918
# Dev Accuracy: 0.8643465909090909
#
# After 3510 iterations:
# Batch Loss: 0.0007068149
#
# After 3520 iterations:
# Batch Loss: 0.005331901
#
# After 3530 iterations:
# Batch Loss: 0.006867158
#
# After 3540 iterations:
# Batch Loss: 0.0011466029
#
# After 3550 iterations:
# Batch Loss: 0.010850248
#
# After 3560 iterations:
# Batch Loss: 0.004476057
#
# After 3570 iterations:
# Batch Loss: 0.008474034
#
# After 3580 iterations:
# Batch Loss: 0.0066615683
#
# After 3590 iterations:
# Batch Loss: 0.016894687
#
# After 3600 iterations:
# Batch Loss: 0.013520505
# Dev Accuracy: 0.8579545454545454
#
# After 3610 iterations:
# Batch Loss: 0.047121845
#
# After 3620 iterations:
# Batch Loss: 0.13322781
#
# After 3630 iterations:
# Batch Loss: 0.010811503
#
# After 3640 iterations:
# Batch Loss: 0.0080727795
#
# After 3650 iterations:
# Batch Loss: 0.0065814694
#
# After 3660 iterations:
# Batch Loss: 0.0054366095
#
# After 3670 iterations:
# Batch Loss: 0.0026638475
#
# After 3680 iterations:
# Batch Loss: 0.008920303
#
# After 3690 iterations:
# Batch Loss: 0.004794276
#
# After 3700 iterations:
# Batch Loss: 0.020674106
# Dev Accuracy: 0.8664772727272727
#
# After 3710 iterations:
# Batch Loss: 0.0011111719
#
# After 3720 iterations:
# Batch Loss: 0.0060581854
#
# After 3730 iterations:
# Batch Loss: 0.015661381
#
# After 3740 iterations:
# Batch Loss: 0.0035871034
#
# After 3750 iterations:
# Batch Loss: 0.0067221625
#
# After 3760 iterations:
# Batch Loss: 0.12575842
#
# After 3770 iterations:
# Batch Loss: 0.022402821
#
# After 3780 iterations:
# Batch Loss: 0.0023851595
#
# After 3790 iterations:
# Batch Loss: 0.007126892
#
# After 3800 iterations:
# Batch Loss: 0.038211092
# Dev Accuracy: 0.8380681818181818
#
# After 3810 iterations:
# Batch Loss: 0.0051428108
#
# After 3820 iterations:
# Batch Loss: 0.0030304198
#
# After 3830 iterations:
# Batch Loss: 0.014187657
#
# After 3840 iterations:
# Batch Loss: 0.015996888
#
# After 3850 iterations:
# Batch Loss: 0.0144884875
#
# After 3860 iterations:
# Batch Loss: 0.010139208
#
# After 3870 iterations:
# Batch Loss: 0.008591226
#
# After 3880 iterations:
# Batch Loss: 0.075414784
#
# After 3890 iterations:
# Batch Loss: 0.01387331
#
# After 3900 iterations:
# Batch Loss: 0.031638432
# Dev Accuracy: 0.8572443181818182
#
# After 3910 iterations:
# Batch Loss: 0.018424027
#
# After 3920 iterations:
# Batch Loss: 0.031751342
#
# After 3930 iterations:
# Batch Loss: 0.009252347
#
# After 3940 iterations:
# Batch Loss: 0.11436495
#
# After 3950 iterations:
# Batch Loss: 0.17564604
#
# After 3960 iterations:
# Batch Loss: 0.008137595
#
# After 3970 iterations:
# Batch Loss: 0.03539919
#
# After 3980 iterations:
# Batch Loss: 0.023063526
#
# After 3990 iterations:
# Batch Loss: 0.0047545843
#
# After 4000 iterations:
# Batch Loss: 0.015662372
# Dev Accuracy: 0.8629261363636364
#
# After 4010 iterations:
# Batch Loss: 0.014343413
#
# After 4020 iterations:
# Batch Loss: 0.0059176986
#
# After 4030 iterations:
# Batch Loss: 0.0078082345
#
# After 4040 iterations:
# Batch Loss: 0.02280681
#
# After 4050 iterations:
# Batch Loss: 0.005684386
#
# After 4060 iterations:
# Batch Loss: 0.07698708
#
# After 4070 iterations:
# Batch Loss: 0.0032233768
#
# After 4080 iterations:
# Batch Loss: 0.00088168983
#
# After 4090 iterations:
# Batch Loss: 0.04468621
#
# After 4100 iterations:
# Batch Loss: 0.016896775
# Dev Accuracy: 0.8565340909090909
#
# After 4110 iterations:
# Batch Loss: 0.048807397
#
# After 4120 iterations:
# Batch Loss: 0.06723426
#
# After 4130 iterations:
# Batch Loss: 0.00086958794
#
# After 4140 iterations:
# Batch Loss: 0.03074815
#
# After 4150 iterations:
# Batch Loss: 0.07246103
#
# After 4160 iterations:
# Batch Loss: 0.011807236
#
# After 4170 iterations:
# Batch Loss: 0.07137124
#
# After 4180 iterations:
# Batch Loss: 0.0075639104
#
# After 4190 iterations:
# Batch Loss: 0.003646756
#
# After 4200 iterations:
# Batch Loss: 0.05876892
# Dev Accuracy: 0.8586647727272727
#
# After 4210 iterations:
# Batch Loss: 0.023112457
#
# After 4220 iterations:
# Batch Loss: 0.05659459
#
# After 4230 iterations:
# Batch Loss: 0.010265336
#
# After 4240 iterations:
# Batch Loss: 0.06923041
#
# After 4250 iterations:
# Batch Loss: 0.003561452
#
# After 4260 iterations:
# Batch Loss: 0.041063868
#
# After 4270 iterations:
# Batch Loss: 0.005894034
#
# After 4280 iterations:
# Batch Loss: 0.056275878
#
# After 4290 iterations:
# Batch Loss: 0.008299387
#
# After 4300 iterations:
# Batch Loss: 0.077255115
# Dev Accuracy: 0.8664772727272727
#
# After 4310 iterations:
# Batch Loss: 0.0057710847
#
# After 4320 iterations:
# Batch Loss: 0.010865454
#
# After 4330 iterations:
# Batch Loss: 0.110147424
#
# After 4340 iterations:
# Batch Loss: 0.011140229
#
# After 4350 iterations:
# Batch Loss: 0.007031028
#
# After 4360 iterations:
# Batch Loss: 0.01917743
#
# After 4370 iterations:
# Batch Loss: 0.009365863
#
# After 4380 iterations:
# Batch Loss: 0.02701317
#
# After 4390 iterations:
# Batch Loss: 0.002024988
#
# After 4400 iterations:
# Batch Loss: 0.036495347
# Dev Accuracy: 0.875
#
# After 4410 iterations:
# Batch Loss: 0.009810604
#
# After 4420 iterations:
# Batch Loss: 0.03679962
#
# After 4430 iterations:
# Batch Loss: 0.017783908
#
# After 4440 iterations:
# Batch Loss: 0.004999485
#
# After 4450 iterations:
# Batch Loss: 0.005864276
#
# After 4460 iterations:
# Batch Loss: 0.002173165
#
# After 4470 iterations:
# Batch Loss: 0.1336313
#
# After 4480 iterations:
# Batch Loss: 0.011021521
#
# After 4490 iterations:
# Batch Loss: 0.002702995
#
# After 4500 iterations:
# Batch Loss: 0.23046272
# Dev Accuracy: 0.8657670454545454
#
# After 4510 iterations:
# Batch Loss: 0.03297498
#
# After 4520 iterations:
# Batch Loss: 0.005333803
#
# After 4530 iterations:
# Batch Loss: 0.00082996534
#
# After 4540 iterations:
# Batch Loss: 0.018577684
#
# After 4550 iterations:
# Batch Loss: 0.009297998
#
# After 4560 iterations:
# Batch Loss: 0.0044038375
#
# After 4570 iterations:
# Batch Loss: 0.017862605
#
# After 4580 iterations:
# Batch Loss: 0.015916336
#
# After 4590 iterations:
# Batch Loss: 0.002299785
#
# After 4600 iterations:
# Batch Loss: 0.07577202
# Dev Accuracy: 0.8501420454545454
#
# After 4610 iterations:
# Batch Loss: 0.0018630904
#
# After 4620 iterations:
# Batch Loss: 0.0024660276
#
# After 4630 iterations:
# Batch Loss: 0.0046932492
#
# After 4640 iterations:
# Batch Loss: 0.01011551
#
# After 4650 iterations:
# Batch Loss: 0.008157213
#
# After 4660 iterations:
# Batch Loss: 0.02328842
#
# After 4670 iterations:
# Batch Loss: 0.11592201
#
# After 4680 iterations:
# Batch Loss: 0.031137954
#
# After 4690 iterations:
# Batch Loss: 0.0044730124
#
# After 4700 iterations:
# Batch Loss: 0.0040335995
# Dev Accuracy: 0.8607954545454546
#
# After 4710 iterations:
# Batch Loss: 0.0149899945
#
# After 4720 iterations:
# Batch Loss: 0.026273284
#
# After 4730 iterations:
# Batch Loss: 0.0028655485
#
# After 4740 iterations:
# Batch Loss: 0.00505696
#
# After 4750 iterations:
# Batch Loss: 0.0062763887
#
# After 4760 iterations:
# Batch Loss: 0.0015397426
#
# After 4770 iterations:
# Batch Loss: 0.17057222
#
# After 4780 iterations:
# Batch Loss: 0.003263911
#
# After 4790 iterations:
# Batch Loss: 0.02113405
#
# After 4800 iterations:
# Batch Loss: 0.009054858
# Dev Accuracy: 0.8636363636363636
#
# After 4810 iterations:
# Batch Loss: 0.004438652
#
# After 4820 iterations:
# Batch Loss: 0.010307467
#
# After 4830 iterations:
# Batch Loss: 0.018701196
#
# After 4840 iterations:
# Batch Loss: 0.0051687337
#
# After 4850 iterations:
# Batch Loss: 0.0053168153
#
# After 4860 iterations:
# Batch Loss: 0.002780576
# After 4870 iterations:
# Batch Loss: 0.0018712685
#
# After 4880 iterations:
# Batch Loss: 0.018692227
#
# After 4890 iterations:
# Batch Loss: 0.0019537294
#
# After 4900 iterations:
# Batch Loss: 0.009711854
# Dev Accuracy: 0.8643465909090909
#
# After 4910 iterations:
# Batch Loss: 0.030263472
#
# After 4920 iterations:
# Batch Loss: 0.05143156
#
# After 4930 iterations:
# Batch Loss: 0.22204125
#
# After 4940 iterations:
# Batch Loss: 0.0031309137
#
# After 4950 iterations:
# Batch Loss: 0.14926158
#
# After 4960 iterations:
# Batch Loss: 0.0063579474
#
# After 4970 iterations:
# Batch Loss: 0.0025264667
#
# After 4980 iterations:
# Batch Loss: 0.010757651
#
# After 4990 iterations:
# Batch Loss: 0.028488707
#
# After 5000 iterations:
# Batch Loss: 0.007413002
# Dev Accuracy: 0.8643465909090909

# %%
saver2.restore(sess, tf.train.latest_checkpoint('log/combo_model'))
# Out:
# INFO:tensorflow:Restoring parameters from log/combo_model/badptr-savepoint-4400

# %%
encoding_1_vars = sorted([(v.name, v) for v in tf.global_variables() if v.name.startswith('encoding_1/Variable')])
encoding_vars = sorted([(v.name, v) for v in tf.global_variables() if v.name.startswith('encoding/Variable')])

# %%
for (n1, e1v), (n, ev) in zip(encoding_1_vars, encoding_vars):
    assert n1.split('/')[1] == n.split('/')[1]
    e1v_val, ev_val = sess.run([e1v, ev])
    assert np.linalg.norm(e1v_val - ev_val) < 1e-10
